# %%
x<-c(2959,3135,2219,3605,2281,3484,2109,3171,3754,2272)
y<-c(75,81,64,79,68,78,52,75,78,73)

# %%
plot(x,y,col="blue", main="Life Expectancy vs. Daily Caloric Intake",xlab="Daily Caloric Intake (2003)", ylab="Life Expectancy (2004)")
# Out:
# Plot with title “Life Expectancy vs. Daily Caloric Intake”

# %%
relation3<-lm(y~x+I(x^2)+I(x^3))
print(relation3)
summary(relation3)
# Out:
# Call:
# lm(formula = y ~ x + I(x^2) + I(x^3))
#
# Coefficients:
# (Intercept)            x       I(x^2)       I(x^3)
#  -9.481e+02    1.017e+00   -3.320e-04    3.571e-08
# Call:
# lm(formula = y ~ x + I(x^2) + I(x^3))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.7032 -2.4584 -0.1955  2.2834  5.3208
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -9.481e+02  4.009e+02  -2.365   0.0559 .
# x            1.017e+00  4.203e-01   2.420   0.0519 .
# I(x^2)      -3.320e-04  1.436e-04  -2.312   0.0601 .
# I(x^3)       3.571e-08  1.605e-08   2.225   0.0678 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.933 on 6 degrees of freedom
# Multiple R-squared:  0.8675,	Adjusted R-squared:  0.8012
# F-statistic: 13.09 on 3 and 6 DF,  p-value: 0.004833

# %%
x_seq <- seq(from=2000,to=4000, by=0.1)
new_relation3<-list(0)
for (i in 1:length(x_seq)) {
    x_new <- data.frame(x=x_seq[i])
    new_relation3[i]<-predict(relation3, x_new)
}
plot(x,y,col="blue", main="Linear Regression Example",lines(x_seq, new_relation3),xlab="x",ylab="y")
# Out:
# Plot with title “Linear Regression Example”

# %%
confint(relation3, level=0.95)
# Out:
#             2.5 %         97.5 %
# (Intercept) -1.929072e+03 3.286460e+01
# x           -1.145906e-02 2.045448e+00
# I(x^2)      -6.833833e-04 1.944696e-05
# I(x^3)      -3.568601e-09 7.498476e-08

# %%
plot(fitted(relation3), residuals(relation3))
# Out:
# plot without title

# %%
relation4<-lm(y~x+I(x^2)+I(x^3)+I(x^4))
print(relation4)
summary(relation4)
# Out:
# Call:
# lm(formula = y ~ x + I(x^2) + I(x^3) + I(x^4))
#
# Coefficients:
# (Intercept)            x       I(x^2)       I(x^3)       I(x^4)
#  -4.129e+03    5.549e+00   -2.720e-03    5.877e-07   -4.722e-11
# Call:
# lm(formula = y ~ x + I(x^2) + I(x^3) + I(x^4))
#
# Residuals:
#        1        2        3        4        5        6        7        8
# -2.22433  4.33350 -1.06489 -0.18101 -2.12325 -0.74772 -0.08638 -1.71928
#        9       10
#  0.29018  3.52317
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -4.129e+03  1.427e+03  -2.894   0.0340 *
# x            5.549e+00  2.011e+00   2.760   0.0398 *
# I(x^2)      -2.720e-03  1.052e-03  -2.587   0.0490 *
# I(x^3)       5.877e-07  2.420e-07   2.428   0.0595 .
# I(x^4)      -4.722e-11  2.068e-11  -2.284   0.0712 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.014 on 5 degrees of freedom
# Multiple R-squared:  0.9351,	Adjusted R-squared:  0.8832
# F-statistic: 18.02 on 4 and 5 DF,  p-value: 0.003579

# %%
x_seq <- seq(from=2000,to=4000, by=0.1)
new_relation4<-list(0)
for (i in 1:length(x_seq)) {
    x_new <- data.frame(x=x_seq[i])
    new_relation4[i]<-predict(relation4, x_new)
}
plot(x,y,col="blue", main="Linear Regression Example",lines(x_seq, new_relation4),xlab="x",ylab="y")
# Out:
# Plot with title “Linear Regression Example”

# %%
confint(relation4, level=0.95)
# Out:
#             2.5 %         97.5 %
# (Intercept) -7.796825e+03 -4.620958e+02
# x            3.804903e-01  1.071746e+01
# I(x^2)      -5.423943e-03 -1.685901e-05
# I(x^3)      -3.448926e-08  1.209879e-06
# I(x^4)      -1.003714e-10  5.935983e-12

# %%
plot(fitted(relation3), residuals(relation3))
# Out:
# plot without title
