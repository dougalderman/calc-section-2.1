# %%
#Problem 1

# %%
x = var('x')

# %%
f = x^2 + 4*x + 5

# %%
d = derivative(f, x)

# %%
d
# Out:
# 2*x + 4

# %%
d.roots()
# Out:
# [(-2, 1)]

# %%
p = []

# %%
p.append(plot(f,(x,-9,5), color='blue', legend_label='f(x)'))

# %%
p.append(plot(d,(x,-9,5), color='red', legend_label='d/dx(f(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#Problem 5

# %%
g = 1 + 6*x + 3*x^2

# %%
d = derivative(g, x)

# %%
d
# Out:
# 6*x + 6

# %%
d.roots()
# Out:
# [(-1, 1)]

# %%
p = []

# %%
p.append(plot(g,(x,-5,3), color='blue', legend_label='g(x)'))

# %%
p.append(plot(d,(x,-5,3), color='red', legend_label='d/dx(g(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#Problem 9

# %%
f = x^3 - 3*x + 6

# %%
d = derivative(f, x)

# %%
d
# Out:
# 3*x^2 - 3

# %%
d.roots()
# Out:
# [(-1, 1), (1, 1)]

# %%
p = []

# %%
p.append(plot(f,(x,-5,5), color='blue', legend_label='f(x)'))

# %%
p.append(plot(d,(x,-5,5), color='red', legend_label='d/dx(f(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#Problem 13

# %%
g = 2*x^3 - 16

# %%
d = derivative(g, x)

# %%
d
# Out:
# 6*x^2

# %%
d.roots()
# Out:
# [(0, 2)]

# %%
p = []

# %%
p.append(plot(g,(x,-5,5), color='blue', legend_label='g(x)'))

# %%
p.append(plot(d,(x,-5,5), color='red', legend_label='d/dx(g(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#Problem 17

# %%
g = x^3 - x^4

# %%
d = derivative(g, x)

# %%
d
# Out:
# -4*x^3 + 3*x^2

# %%
d.roots()
# Out:
# [(3/4, 1), (0, 2)]

# %%
p = []

# %%
p.append(plot(g,(x,-1,1.5), color='blue', legend_label='g(x)'))

# %%
p.append(plot(d,(x,-1,1.5), color='red', legend_label='d/dx(g(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#Problem 21

# %%
g = 2 * x^4 - 20 * x^2 + 18

# %%
d = derivative(g, x)

# %%
d
# Out:
# 8*x^3 - 40*x

# %%
d.roots()
# Out:
# [(-sqrt(5), 1), (sqrt(5), 1), (0, 1)]

# %%
p = []

# %%
p.append(plot(g,(x,-3.5,3.5), color='blue', legend_label='g(x)'))

# %%
p.append(plot(d,(x,-3.5,3.5), color='red', legend_label='d/dx(g(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#Problem 25

# %%
f = 1 - x^(2/3)

# %%
d = derivative(f, x)

# %%
d
# Out:
# -2/3/x^(1/3)

# %%
d.roots()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-d6ece07eb299> in <module>
# ----> 1 d.roots()
#
# /ext/sage/9.4/local/lib/python3.9/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.roots (build/cythonized/sage/symbolic/expression.cpp:62122)()
#   11845         S, mul = self.solve(x, multiplicities=True, explicit_solutions=explicit_solutions)
#   11846         if len(mul) == 0 and explicit_solutions:
# > 11847             raise RuntimeError("no explicit roots found")
#   11848         else:
#   11849             rt_muls = [(S[i].rhs(), mul[i]) for i in range(len(mul))]
#
# RuntimeError: no explicit roots found

# %%
f_plot = 1 - abs(x)^(2/3)

# %%
d_plot = -2/3/sign(x)*abs(x)^(1/3)

# %%
p = []

# %%
p.append(plot(f_plot,(x,-2,2), color='blue', legend_label='f(x)'))

# %%
p.append(plot(d_plot,(x,-2,2), color='red', legend_label='d/dx(f(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#Problem 29

# %%
g = 4*x/(x^2 + 1)

# %%
d = derivative(g, x)

# %%
d
# Out:
# -8*x^2/(x^2 + 1)^2 + 4/(x^2 + 1)

# %%
d.roots()
# Out:
# [(-1, 1), (1, 1)]

# %%
p = []

# %%
p.append(plot(g,(x,-3,3), color='blue', legend_label='g(x)'))

# %%
p.append(plot(d,(x,-3,3), color='red', legend_label='d/dx(g(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#Problem 33

# %%
g = sqrt(x^2 + 2*x + 5)

# %%
d = derivative(g, x)

# %%
d
# Out:
# (x + 1)/sqrt(x^2 + 2*x + 5)

# %%
d.roots()
# Out:
# [(-1, 1)]

# %%
p = []

# %%
p.append(plot(g,(x,-4,2), color='blue', legend_label='g(x)'))

# %%
p.append(plot(d,(x,-4,2), color='red', legend_label='d/dx(g(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#Problem 91

# %%
f = -x^6 - 4*x^5 + 54*x^4 + 160*x^3 - 641*x^2 - 828*x + 1200

# %%
d = derivative(f, x)

# %%
d
# Out:
# -6*x^5 - 20*x^4 + 216*x^3 + 480*x^2 - 1282*x - 828

# %%
find_root(d, -10, -5)
# Out:
# -6.261700675916321

# %%
find_root(d, -5, -1)
# Out:
# -3.682857965431111

# %%
find_root(d, -1, 1)
# Out:
# -0.5594527394958978

# %%
find_root(d, 1, 4)
# Out:
# 2.116245125368916

# %%
find_root(d, 4, 10)
# Out:
# 5.054432922141072

# %%
p = []

# %%
p.append(plot(f,(x,-7,7), color='blue', legend_label='f(x)'))

# %%
p.append(plot(d,(x,-7,7), color='red', legend_label='d/dx(f(x))'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
def f(x): return -x^6 - 4*x^5 + 54*x^4 + 160*x^3 - 641*x^2 - 828*x + 1200

# %%
f(-6.261700675916321)
# Out:
# 3213.79548076411

# %%
f(-3.682857965431111)
# Out:
# -2288.02940385335

# %%
f(-0.5594527394958978)
# Out:
# 1440.06415994824

# %%
f(2.116245125368916)
# Out:
# -1083.08409256786

# %%
f(5.054432922141072)
# Out:
# 6674.12079672394

# %%
#Problem 95

# %%
f = -4.722e-11*x^4 + 5.877e-7*x^3 - 2.720e-3*x^2 + 5.549*x - 4129

# %%
d = derivative(f, x)

# %%
d
# Out:
# -(1.88880000000000e-10)*x^3 + (1.76310000000000e-6)*x^2 - 0.00544000000000000*x + 5.54900000000000

# %%
find_root(d, 2500, 3000)
# Out:
# 2641.9874487606808

# %%
find_root(d, 3000, 3500)
# Out:
# 3067.6903358744353

# %%
find_root(d, 3500, 4000)
# Out:
# 3624.8203093927923

# %%
plot(f,(x,2000,4000), color='blue', legend_label='f(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(d,(x,2000,4000), color='red', legend_label='d/dx(f(x))')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def f(x): return -4.722e-11*x^4 + 5.877e-7*x^3 - 2.720e-3*x^2 + 5.549*x - 4129

# %%
f(2641.987)
# Out:
# 82.8508987307705

# %%
f(3067.690)
# Out:
# 80.9809282412680

# %%
f(3624.820)
# Out:
# 84.8148405374595
